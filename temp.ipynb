# %%
import pandas as pd

# %%
pd.read_feather("/home/haris/data/IndexWeightData/20150105.fea").index_name.unique()
# Out:
# array(['HS300', 'A500', 'ZZ1000', 'ZZ500', 'ZZ2000'], dtype=object)

# %%
pd.read_feather("/home/haris/data/IndexWeightData/20150105.fea")
# Out:
#           date index_code index_name stock_code  stock_weight
# 0     20150105     000300      HS300     000001      1.074910
# 1     20150105     000300      HS300     000002      1.601711
# 2     20150105     000300      HS300     000009      0.231563
# 3     20150105     000300      HS300     000024      0.323989
# 4     20150105     000300      HS300     000027      0.105118
# ...        ...        ...        ...        ...           ...
# 2554  20150105     932000     ZZ2000     300344      0.234000
# 2555  20150105     932000     ZZ2000     300341      0.236000
# 2556  20150105     932000     ZZ2000     300354      0.206000
# 2557  20150105     932000     ZZ2000     603009      0.177000
# 2558  20150105     932000     ZZ2000     300390      0.149000
#
# [2559 rows x 5 columns]
