# %%
from src.backtest_engine import run_backtest

result = run_backtest()

print(result["info"])
# Out:
# /home/user0/project/backtester/src/data_loader.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   last_zt_df = (close == high_limit).shift(1).fillna(False).astype(int)
# 预加载数据...
#   0%|          | 0/1155 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.backtest_engine import run_backtest
# ----> 3 result = run_backtest()
#       5 print(result["info"])
#
# File ~/project/backtester/src/backtest_engine.py:31, in run_backtest()
#      25 s.date = str_date
#      27 td_open, td_close, td_preclose, td_adj, td_score, td_upper, td_lower, last_zt = get_daily_price(
# ...
